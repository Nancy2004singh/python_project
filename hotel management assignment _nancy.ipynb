# %% [markdown]
# # Assignment.

# %% [markdown]
# with file

# %%
import os  

def restaurant_bill():
    global se
    e=int(input("enter room number"))
    hotel= str(e)+'.txt'
    if os.path.isfile(hotel):
        f1=open(hotel,'w')
        data=dic
        print(f"Record found .customer name :{dic[e]['name']}")
        print('')
        print("------------ RESTAURANT MENU---------------")
        print(" ")
        print("1 water(Rs 20).\n2 Tea (Rs 10).\n3 breakfast combo (Rs 90).\n4 Lunch (Rs 110).\n5 Dinner (Rs 150).\n6 Exit")
        for i in range(20):
            co=int(input("Enter the choice :"))
            if co!=6 :
                vo=int(input("Enter the quantity :"))
                if co==1:
                    se+=vo*20 
                if co==2:
                    se+=vo*10
                elif co==3:
                    se+=vo*90
                elif co==4:
                    se+=vo*110
                elif co==5:
                    se+=vo*150
                dic[e]['restaurant_bill']=se    
            elif co==6:    
                print(f"Restaurant bill =  Rs {se}")
                break
                f1.write(str(data))
                f1.close()
                exit()    

        continu()
    else:
        print("Record not found. room is not booked")
        
def laundary():
    global d
    e=int(input("enter room no."))
    hotel=str(e)+'.txt'
    if os.path.isfile(hotel):
        f1=open(hotel,'w')
        data=dic
        print(f"Record found .customer name :{dic[e]['name']}")
        print('')
        print("------ laundary menu -------")
        print(" ")
        print("1 Shorts (Rs 3) .\n2 Trousers (Rs 4) .\n3 Shirt (Rs 5) .\n4 Jeans (Rs 7) .\n5 girl saree/suit (Rs 8) .\n6 Exit")
        for i in range(30):
            s=int(input("Enter the choice:"))
            if s!=6:
                w=int(input("Enter the quantity:"))
                if s==1:
                    d+=w*3
                if s==2:
                    d+=w*4
                elif s==3:
                    d+=w*5
                elif s==4:
                    d+=w*7
                elif s==5:
                    d+=w*8
                dic[e]['laundary_bill']=d    
            else:
                print(f"Total laundary bill is  Rs {d}")
                break
                f1.write(str(data))
                f1.close()
                exit()
        
    else:
        print("Record not found, room is not booked")
        
def games():
    global j
    s=int(input("enter room number"))
    hotel=str(s)+".txt"
    if os.path.isfile(hotel):
        f1=open(hotel,'w')
        data=dic
        print(f"Record found .customer name :{dic[s]['name']}")
        print('')
        print("=========== Game menu ===========")
        print(" ")
        print("1 table tenis (Rs 60) .\n2 Bowling (Rs 80) .\n3 Snooker (Rs 70) .\n4 Video game (Rs 90) .\n5 Pool (Rs 50) .\n6 Exit")
        for i in range(30):
            g=int(input("Enter the choice:"))
            if g!=6:
                k=int(input("No of hours :"))
                if g==1:
                    j+=k*60
                if g==2:
                    j+=k*80
                elif g==3:
                    j+=k*70
                elif g==4:
                    j+=k*90
                elif g==5:
                    j+=k*50
                dic[s]['gaming_bill']=j    
            else:
                print(f"Gaming bill is  Rs {j}")
                break
                f1.write(str(data))
                f1.close()
                exit()
        
    else:
        print("Record not found ,room is not booked")
    
    
def customer_data():
    
    global dic
    print("Enter Customer Details")
    b=int(input("Enter room number :"))
    hotel = str(b) +'.txt'
    if os.path.isfile(hotel):
        print("This room is already booked.")
    else:
        f1=open(hotel,'w')
        c=input("Customer name: ")
        d=input("Address: ")
        e=int(input("Phone number: "))
        f=input("Checkin date : ")
        g=input("Checkout date : ")
        dic[b]={'name':c,"address":d,"phone number":e,"checkin":f,"checkout":g,'room_rent_bill':y,'restaurant_bill':se,'laundary_bill':d,'gaming_bill':j,'sub total_bill':sa,'Grand total_bill':q}
        f1.write(str(dic))
        f1.close()
        print("File has created..")
        h=input("Do you want to booked more rooms (Y/N):").upper()
        if h=='Y':
            customer_data()
        else :
            exit()   

def roomrent():
    global y
    w=int(input("Room no :"))
    hotel=str(w)+'.txt'
    if os.path.isfile(hotel):
        f1=open(hotel,'w')
        data=dic
        print(f"Record found .customer name :{dic[w]['name']}")
        print('')
        print("===== ROOM RENT MENU ======")
        print('')
        print("1 Type A(Rs 6000 per night).\n2 Type B (Rs 5000 per night).\n3 Type C(Rs 4000 per night).\n4 Type D(Rs 3000 per night) .\n5 Exit")
        ew=int(input("Enter the choise :"))
        if ew!=5:
            qw=int(input("No of nights you stay :"))
            if ew ==1:
                y=6000*qw
                print(f"Room rent= Rs {y}")
            elif ew==2:
                y=5000*qw
                print(f"Room rent= Rs {y}")
            elif ew==3:
                y=4000*qw
                print(f"Room rent= Rs {y}")
            elif ew==4:
                y=3000*qw
            dic[w]['room_rent_bill']=y   
        else:       
            print(f"Room rent= Rs {y}")
            f1.write(str(data))
            f1.close()
            exit()
    else:
        print("room is not booked")

        
def total_cost(): 
    global sa
    global z
    s=int(input("Enter the room number"))
    hotel=str(s)+'.txt'
    if os.path.isfile(hotel):
        f1=open(hotel,'w')
        data=dic
        print(f"Record found .customer name :{dic[s]['name']}")
        print('')
        print("*********HOTEL BILL***********")
        print("     CUSTOMER DETAILS   ")
        print(f"Customer name :{dic[s]['name']} .\n Address: {dic[s]['address']} .\n checkin date: {dic[s]['checkin']} .\n checkout date:{dic[s]['checkout']} .\n Room rent = Rs{y} .\n food bill = Rs{se} .\n laundary bill = Rs{d} .\n Gaming bill = Rs{j}")
        sa=j+d+se+y
        print(f"Sub total bill = Rs {sa}")
        w=sa*18/100
        print(f"Additional Service charges(18%) = {w}")
        q=w+sa
        print(f"Grand total bill : {q}")
        dic[s]['Grand total_']=q
        dic[s]['sub total_bill']=sa
        f1.write(str(data))
        f1.close()
        continu()
    else :
        print("Record not found,room is not booked")

def continu():
    wp=input("Do you want to continue (Y/N) ?").upper()
    if wp=='N':
        exit()
    elif wp=='Y':
        hotel()
    elif wp!='Y' or wp!='N':
        print("Enter the valid choice: ")
        continu()

def hotel():
    print("=========================================================")
    print("             WELCOME TO COUNTRY INN HOTEL                ")
    print("=========================================================")
    print('')
    print("please choose Any one option .\n1 Enter customer data .\n2 Calculate roomrent .\n3 calculate restaurant bill .\n4 calculate laundary bill .\n5 calculate game bill .\n6 check total cost .\n7 Exit ")
    print('')
    a=int(input("Enter the choise from 1 to 7 :"))
    if a==7:
        exit()
    if a==1:
        customer_data()
        continu()
    elif a==2:
        roomrent()
        continu()
    elif a==3:
        restaurant_bill()
    elif a==4:
        laundary()
        continu()
    elif a==5:
        games()
        continu()
    elif a==6:
        total_cost()

# %%
dic={}
j,d,se,y,q,sa=0,0,0,0,0,0
hotel()
# Out:
# ...
#              WELCOME TO COUNTRY INN HOTEL
# ...
#
# please choose Any one option .
# 1 Enter customer data .
# 2 Calculate roomrent .
# 3 calculate restaurant bill .
# 4 calculate laundary bill .
# 5 calculate game bill .
# 6 check total cost .
# 7 Exit
#
# Enter the choise from 1 to 7 :1
# Enter Customer Details
# Enter room number :1
# This room is already booked.
# Do you want to continue (Y/N) ?n

# %% [markdown]
# # with dictionary

# %%
def iteams(e):
    global se
    for i in range(20):
        co=int(input("Enter the choice :"))
        if co!=6 :
            vo=int(input("Enter the quantity :"))
            if co==1:
                se+=vo*20 
            if co==2:
                se+=vo*10
            elif co==3:
                se+=vo*90
            elif co==4:
                se+=vo*110
            elif co==5:
                se+=vo*150
        elif co==6:    
            print(f"Restaurant bill =  Rs {se}")
            break
            exit()    

def restaurant_bill(e):
    if e in dic:
        print(f"Record found .customer name :{dic[e]['name']}")
        print('')
        print("------------ RESTAURANT MENU---------------")
        print(" ")
        print("1 water(Rs 20).\n2 Tea (Rs 10).\n3 breakfast combo (Rs 90).\n4 Lunch (Rs 110).\n5 Dinner (Rs 150).\n6 Exit")
        iteams(e)
        continu()
    else:
        print("Record not found.")
        w=int(input("Please enter room number again :"))
        restaurant_bill(w)
        
def laundary(e):
    if e in dic:
        global d
        print(f"Record found .customer name :{dic[e]['name']}")
        print('')
        print("------ laundary menu -------")
        print(" ")
        print("1 Shorts (Rs 3) .\n2 Trousers (Rs 4) .\n3 Shirt (Rs 5) .\n4 Jeans (Rs 7) .\n5 girl saree/suit (Rs 8) .\n6 Exit")
        for i in range(50):
            s=int(input("Enter the choice:"))
            if s!=6:  
                w=int(input("Enter the quantity:"))
                if s==1:
                    d+=w*3
                if s==2:
                    d+=w*4
                elif s==3:
                    d+=w*5
                elif s==4:
                    d+=w*7
                elif s==5:
                    d+=w*8
            else:
                print(f"Total laundary bill is  Rs {d}")
                break
                exit()
        
    else:
        print("Record not found")
        s=int(input("Please enter room no again:"))
        laundary(s)
        
def games():
    s=int(input("Enter the room no: "))
    if s in dic:
        global j
        print(f"Record found .customer name :{dic[s]['name']}")
        print('')
        print("=========== Game menu ===========")
        print(" ")
        print("1 table tenis (Rs 60) .\n2 Bowling (Rs 80) .\n3 Snooker (Rs 70) .\n4 Video game (Rs 90) .\n5 Pool (Rs 50) .\n6 Exit")
        for i in range(30):
            g=int(input("Enter the choice:"))
            if g!=6:
                k=int(input("No of hours :"))
                if g==1:
                    j+=k*60
                if g==2:
                    j+=k*80
                elif g==3:
                    j+=k*70
                elif g==4:
                    j+=k*90
                elif g==5:
                    j+=k*50
            else:
                print(f"Gaming bill is  Rs {j}")
                break
                exit()
        
    else:
        print("Record not found this room is not booked")
        e=int(input("Please enter correct room no:"))
        games(e)
    
    
def customer_data():
    
    global dic
    print("Enter Customer Details")
    b=int(input("Enter room number : "))
    c=input("Customer name: ")
    d=input("Address: ")
    e=int(input("Phone number: "))
    f=input("Checkin date : ")
    g=input("Checkout date : ")
    dic[b]={'name':c,"address":d,"phone number":e,"checkin":f,"checkout":g}
    print("File has created..")
    h=input("Do you want to booked more rooms (Y/N): ").upper()
    if h=='Y':
        customer_data()
    else :
        exit()   

def roomrent():
    global w
    w=int(input("Room no : "))
    if w in dic:
        global y
        print(f"Record found .customer name :{dic[w]['name']}")
        print('')
        print("===== ROOM RENT MENU ======")
        print('')
        print("1 Type A(Rs 6000 per night).\n2 Type B (Rs 5000 per night).\n3 Type C(Rs 4000 per night).\n4 Type D(Rs 3000 per night) .\n5 Exit")
        ew=int(input("Enter the choise : "))
        if ew!=5:
            qw=int(input("No of nights you stay :"))
            if ew ==1:
                y=6000*qw
                print(f"Room rent= Rs {y}")
            elif ew==2:
                y=5000*qw
                print(f"Room rent= Rs {y}")
            elif ew==3:
                y=4000*qw
                print(f"Room rent= Rs {y}")
            elif ew==4:
                y=3000*qw
        else:       
            print(f"Room rent= Rs {y}")
            exit()

    else:
        print("Record not found.")
        w=int(input("Please Enter room number again :"))
        roomrent(w)
        
def total_cost(s):
    if s in dic:
        print(f"Record found .customer name : {dic[s]['name']}")
        print('')
        print("*********HOTEL BILL***********")
        print("     CUSTOMER DETAILS   ")
        print(f"Customer name : {dic[s]['name']} .\n Address: {dic[s]['address']} .\n checkin date: {dic[s]['checkin']} .\n checkout date:{dic[s]['checkout']} .\n Room rent = Rs{y} .\n food bill = Rs{se} .\n laundary bill = Rs{d} .\n Gaming bill = Rs{j}")
        sum=j+d+se+y
        print(f"Sub total bill = Rs {sum}")
        w=sum*18/100
        print(f"Additional Service charges(18%) = {w}")
        print(f"Grand total bill : {w+sum}")
        continu()
    else :
        print("Record not found")
        e=int(input("please enter correct room no : "))
        total_cost(e)

def continu():
    wp=input("Do you want to continue (Y/N) ? ").upper()
    if wp=='N':
        exit()
    elif wp=='Y':
        hotel()
    elif wp!='Y' or wp!='N':
        print("Enter the valid choice")
        continu()

def hotel():
    print("=========================================================")
    print("             WELCOME TO COUNTRY INN HOTEL                ")
    print("=========================================================")
    print('')
    print("please choose Any one option .\n1 Enter customer data .\n2 Calculate roomrent .\n3 calculate restaurant bill .\n4 calculate laundary bill .\n5 calculate game bill .\n6 check total cost .\n7 Exit ")
    print('')
    a=int(input("Enter the choise from 1 to 7 :"))
    if a==7:
        exit()
    if a==1:
        customer_data()
        continu()
    elif a==2:
        roomrent()
        continu()
    elif a==3:
        er=int(input("Room no : "))
        restaurant_bill(er)
    elif a==4:
        er=int(input("Enter room no : "))
        laundary(er)
        continu()
    elif a==5:
        games()
        continu()
    elif a==6:
        er=int(input("Enter room no :"))
        total_cost(er)
        
dic={}
j,d,se,y=0,0,0,0
hotel()
# Out:
# ...
#              WELCOME TO COUNTRY INN HOTEL
# ...
#
# please choose Any one option .
# 1 Enter customer data .
# 2 Calculate roomrent .
# 3 calculate restaurant bill .
# 4 calculate laundary bill .
# 5 calculate game bill .
# 6 check total cost .
# 7 Exit
#
# Enter the choise from 1 to 7 :1
# Enter Customer Details
# Enter room number : 10
# Customer name: nancy
# Address: delhi
# Phone number: 456987654
# Checkin date : 1/2/24
# Checkout date : 6/2/24
# File has created..
# Do you want to booked more rooms (Y/N): n
# Do you want to continue (Y/N) ? y
# ...
#              WELCOME TO COUNTRY INN HOTEL
# ...
#
# please choose Any one option .
# 1 Enter customer data .
# 2 Calculate roomrent .
# 3 calculate restaurant bill .
# 4 calculate laundary bill .
# 5 calculate game bill .
# 6 check total cost .
# 7 Exit
#
# Enter the choise from 1 to 7 :2
# Room no : 10
# Record found .customer name :nancy
#
# ===== ROOM RENT MENU ======
#
# 1 Type A(Rs 6000 per night).
# 2 Type B (Rs 5000 per night).
# ...
